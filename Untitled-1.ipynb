# %% [markdown]
# Análise escola Estaduais - SP

# %%
#importando as libs
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
#lendo os 2 arquivos e selecionando apenas as colunas desejadas do arquivo 2
    ###listaColunas = list(df2.columns.values)
df = pd.read_csv('escola.csv')
df2=pd.read_csv('Miest_2021_03.csv', usecols=[
 'DE',
 'CODMUN',
 'MUN',
 'TIPOESC',
 'Tipo_Escola',
 'CODVINC',
 'COD_ESC',
 'NOMESC',
 'ENDESC',
 'NUMESC',
 'COMPLEND',
 'BAIESC',
 'CEP',
 'DS_LATITUDE',
 'DS_LONGITUDE',
 'SALAS_AULA',
 'FLAG_PEI',
 'FLAG_ETI',
 'FLAG-TURNO-MANHA',
 'FLAG-TURNO-INTERMEDIARIO',
 'FLAG-TURNO-TARDE',
 'FLAG-TURNO-VESPERTINO',
 'FLAG-TURNO-NOITE',
 'FLAG-TURNO-INTEGRAL',
 'FLAG-EJA',
 'FLAG-EJA-EM',
 'FLAG-EM',
 'ALEM1S',
 'ALEM2S',
 'ALEM3S',
 'ALEM4S',
 'ALEMNS',
 'Tempo_integral'])

# %%
#verificando as colunas importadas do arquivo 2
df2.columns
# Out:
# Index(['DE', 'CODMUN', 'MUN', 'TIPOESC', 'Tipo_Escola', 'CODVINC', 'COD_ESC',
#        'NOMESC', 'ENDESC', 'NUMESC', 'COMPLEND', 'BAIESC', 'CEP',
#        'DS_LATITUDE', 'DS_LONGITUDE', 'SALAS_AULA', 'FLAG_PEI', 'FLAG_ETI',
#        'FLAG-TURNO-MANHA', 'FLAG-TURNO-INTERMEDIARIO', 'FLAG-TURNO-TARDE',
#        'FLAG-TURNO-VESPERTINO', 'FLAG-TURNO-NOITE', 'FLAG-TURNO-INTEGRAL',
#        'FLAG-EJA', 'FLAG-EJA-EM', 'FLAG-EM', 'ALEM1S', 'ALEM2S', 'ALEM3S',
#        'ALEM4S', 'ALEMNS', 'Tempo_integral'],
#       dtype='object')

# %%
#Lendo o arquivo 1
df.head()
# Out:
#    id_municipio      rede diretoria  id_escola  id_escola_sp  \
# 0       3550308  estadual   NORTE 1   35000012            12
# 1       3550308  estadual   NORTE 1   35000024            24
# 2       3550308  estadual   NORTE 1   35000036            36
# 3       3550308  estadual   NORTE 1   35000048            48
# 4       3550308  estadual   NORTE 1   35000059            59
#
#    nivel_socio_economico
# 0                   2.71
# 1                   3.93
# 2                   4.02
# 3                   4.27
# 4                   4.04

# %%
#Juntando os arquivos pelo código e mostrando as colunas do novo dataframe
df3 = df2.merge(df,left_on='COD_ESC', right_on='id_escola_sp', how='left')
df3.columns
# Out:
# Index(['DE', 'CODMUN', 'MUN', 'TIPOESC', 'Tipo_Escola', 'CODVINC', 'COD_ESC',
#        'NOMESC', 'ENDESC', 'NUMESC', 'COMPLEND', 'BAIESC', 'CEP',
#        'DS_LATITUDE', 'DS_LONGITUDE', 'SALAS_AULA', 'FLAG_PEI', 'FLAG_ETI',
#        'FLAG-TURNO-MANHA', 'FLAG-TURNO-INTERMEDIARIO', 'FLAG-TURNO-TARDE',
#        'FLAG-TURNO-VESPERTINO', 'FLAG-TURNO-NOITE', 'FLAG-TURNO-INTEGRAL',
#        'FLAG-EJA', 'FLAG-EJA-EM', 'FLAG-EM', 'ALEM1S', 'ALEM2S', 'ALEM3S',
#        'ALEM4S', 'ALEMNS', 'Tempo_integral', 'id_municipio', 'rede',
#        'diretoria', 'id_escola', 'id_escola_sp', 'nivel_socio_economico'],
#       dtype='object')

# %%
#verificando o tipo de dado
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28776 entries, 0 to 28775
# Data columns (total 39 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DE                        28776 non-null  object
#  1   CODMUN                    28775 non-null  float64
#  2   MUN                       28776 non-null  object
#  3   TIPOESC                   28776 non-null  int64
#  4   Tipo_Escola               28776 non-null  object
#  5   CODVINC                   28776 non-null  int64
#  6   COD_ESC                   28776 non-null  int64
#  7   NOMESC                    28776 non-null  object
#  8   ENDESC                    28750 non-null  object
#  9   NUMESC                    28551 non-null  object
#  10  COMPLEND                  23678 non-null  object
#  11  BAIESC                    28749 non-null  object
#  12  CEP                       28775 non-null  float64
#  13  DS_LATITUDE               27978 non-null  object
#  14  DS_LONGITUDE              27978 non-null  object
#  15  SALAS_AULA                28750 non-null  float64
#  16  FLAG_PEI                  28776 non-null  int64
#  17  FLAG_ETI                  28776 non-null  int64
#  18  FLAG-TURNO-MANHA          28776 non-null  int64
#  19  FLAG-TURNO-INTERMEDIARIO  28776 non-null  int64
#  20  FLAG-TURNO-TARDE          28776 non-null  int64
#  21  FLAG-TURNO-VESPERTINO     28776 non-null  int64
#  22  FLAG-TURNO-NOITE          28776 non-null  int64
#  23  FLAG-TURNO-INTEGRAL       28776 non-null  int64
#  24  FLAG-EJA                  28776 non-null  int64
#  25  FLAG-EJA-EM               28776 non-null  int64
#  26  FLAG-EM                   28776 non-null  int64
#  27  ALEM1S                    28776 non-null  int64
#  28  ALEM2S                    28776 non-null  int64
#  29  ALEM3S                    28776 non-null  int64
#  30  ALEM4S                    28776 non-null  int64
#  31  ALEMNS                    28776 non-null  int64
#  32  Tempo_integral            28776 non-null  object
#  33  id_municipio              5060 non-null   float64
#  34  rede                      5060 non-null   object
#  35  diretoria                 5060 non-null   object
#  36  id_escola                 5060 non-null   float64
#  37  id_escola_sp              5060 non-null   float64
#  38  nivel_socio_economico     5060 non-null   float64
# dtypes: float64(7), int64(19), object(13)
# memory usage: 8.8+ MB

# %%
#verificando os tipos de escola
list(df3['Tipo_Escola'].unique())
# Out:
# ['08 - EE',
#  '00 - NAO DEFINIDO',
#  '40 - PRIVADA - FILANTRÓPICA',
#  '48 - PRIVADA - COMUNITARIA',
#  '50 - CIEJA',
#  '10 - EEI',
#  '11 - PAULA SOUZA',
#  '34 - FEBEM - UI (CASA À PARTIR DE 2007)',
#  '13 - SENAI',
#  '09 - FEBEM - UIP (CASA À PARTIR DE 2007)',
#  '12 - SENAC',
#  '14 - SESI - CE',
#  '57 - EAD/Presencial',
#  '15 - CLASSE PENITENCIÁRIA',
#  '51 - PRIVADA CONFESSIONAL',
#  '38 - EDUCAÇÃO PROFISSIONAL - QUALIFICAÇÃO BÁSICA',
#  '01 - APAE',
#  '44 - ESCOLA EXCLUSIVA DE EDUCAÇÃO COMPLEMENTAR',
#  '02 - CCI',
#  '28 - USP',
#  '37 - EDUACAÇÃO À DISTÂNCIA',
#  '41 - EJA - CURSO PREPARATÓRIO',
#  '26 - UNESP',
#  '03 - CEEJA',
#  '31 - QUILOMBO',
#  '36 - ÁREA DE ASSENTAMENTO',
#  '27 - UNICAMP',
#  '39 - SENAI - DISTÂNCIA/BÁSICA',
#  '54 - Proeja/Fundamental']

# %%
#selecionando quais tipos vamos manter na nossa base
tipoEscola = ['08 - EE', '11 - PAULA SOUZA']
df = df3[df3['Tipo_Escola'].isin(tipoEscola)]

# %%
#verificando o tamanho da base atual
df.shape
# Out:
# (5281, 39)

# %%
df.columns
# Out:
# Index(['DE', 'CODMUN', 'MUN', 'TIPOESC', 'Tipo_Escola', 'CODVINC', 'COD_ESC',
#        'NOMESC', 'ENDESC', 'NUMESC', 'COMPLEND', 'BAIESC', 'CEP',
#        'DS_LATITUDE', 'DS_LONGITUDE', 'SALAS_AULA', 'FLAG_PEI', 'FLAG_ETI',
#        'FLAG-TURNO-MANHA', 'FLAG-TURNO-INTERMEDIARIO', 'FLAG-TURNO-TARDE',
#        'FLAG-TURNO-VESPERTINO', 'FLAG-TURNO-NOITE', 'FLAG-TURNO-INTEGRAL',
#        'FLAG-EJA', 'FLAG-EJA-EM', 'FLAG-EM', 'ALEM1S', 'ALEM2S', 'ALEM3S',
#        'ALEM4S', 'ALEMNS', 'Tempo_integral', 'id_municipio', 'rede',
#        'diretoria', 'id_escola', 'id_escola_sp', 'nivel_socio_economico'],
#       dtype='object')

# %%
#Melhorando a base
df['TotalAlunosEM'] = df['ALEM1S']+df['ALEM2S']+df['ALEM3S']+df['ALEM4S']
# Out:
# C:\Users\51048726\AppData\Local\Temp\ipykernel_92788\154075574.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TotalAlunosEM'] = df['ALEM1S']+df['ALEM2S']+df['ALEM3S']+df['ALEM4S']

# %%
df['COD_ESC'] = df['COD_ESC'].astype(str)
# Out:
# C:\Users\51048726\AppData\Local\Temp\ipykernel_92788\2471597537.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['COD_ESC'] = df['COD_ESC'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5281 entries, 0 to 28774
# Data columns (total 40 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DE                        5281 non-null   object
#  1   CODMUN                    5281 non-null   float64
#  2   MUN                       5281 non-null   object
#  3   TIPOESC                   5281 non-null   int64
#  4   Tipo_Escola               5281 non-null   object
#  5   CODVINC                   5281 non-null   int64
#  6   COD_ESC                   5281 non-null   object
#  7   NOMESC                    5281 non-null   object
#  8   ENDESC                    5280 non-null   object
#  9   NUMESC                    5261 non-null   object
#  10  COMPLEND                  4821 non-null   object
#  11  BAIESC                    5280 non-null   object
#  12  CEP                       5281 non-null   float64
#  13  DS_LATITUDE               5281 non-null   object
#  14  DS_LONGITUDE              5281 non-null   object
#  15  SALAS_AULA                5281 non-null   float64
#  16  FLAG_PEI                  5281 non-null   int64
#  17  FLAG_ETI                  5281 non-null   int64
#  18  FLAG-TURNO-MANHA          5281 non-null   int64
#  19  FLAG-TURNO-INTERMEDIARIO  5281 non-null   int64
#  20  FLAG-TURNO-TARDE          5281 non-null   int64
#  21  FLAG-TURNO-VESPERTINO     5281 non-null   int64
#  22  FLAG-TURNO-NOITE          5281 non-null   int64
#  23  FLAG-TURNO-INTEGRAL       5281 non-null   int64
#  24  FLAG-EJA                  5281 non-null   int64
#  25  FLAG-EJA-EM               5281 non-null   int64
#  26  FLAG-EM                   5281 non-null   int64
#  27  ALEM1S                    5281 non-null   int64
#  28  ALEM2S                    5281 non-null   int64
#  29  ALEM3S                    5281 non-null   int64
#  30  ALEM4S                    5281 non-null   int64
#  31  ALEMNS                    5281 non-null   int64
#  32  Tempo_integral            5281 non-null   object
#  33  id_municipio              5043 non-null   float64
#  34  rede                      5043 non-null   object
#  35  diretoria                 5043 non-null   object
#  36  id_escola                 5043 non-null   float64
#  37  id_escola_sp              5043 non-null   float64
#  38  nivel_socio_economico     5043 non-null   float64
#  39  TotalAlunosEM             5281 non-null   int64
# dtypes: float64(7), int64(19), object(14)
# memory usage: 1.7+ MB

# %%
#mun com mais escolas
EscMun = df.groupby('MUN').size().sort_values(ascending=False)
EscMun.head(10)
# Out:
# MUN
# SAO PAULO                1122
# GUARULHOS                 169
# CAMPINAS                  163
# SANTO ANDRE                88
# SOROCABA                   81
# SAO JOSE DOS CAMPOS        76
# SAO BERNARDO DO CAMPO      73
# RIBEIRAO PRETO             70
# MAUA                       64
# PIRACICABA                 60
# dtype: int64

# %%
df.groupby('MUN').agg({
    'COD_ESC':'count'
    ,'TotalAlunosEM':['sum','mean','median']
    ,'nivel_socio_economico':['mean', 'median']}
    ).sort_values(('COD_ESC','count'), ascending=False)
# Out:
#                  COD_ESC TotalAlunosEM                     \
#                    count           sum        mean median
# MUN
# SAO PAULO           1122        328423  292.712121  175.0
# GUARULHOS            169         49306  291.751479  241.0
# CAMPINAS             163         29500  180.981595  125.0
# SANTO ANDRE           88         19215  218.352273  167.5
# SOROCABA              81         20400  251.851852  219.0
# ...                  ...           ...         ...    ...
# NARANDIBA              1           150  150.000000  150.0
# NANTES                 1            95   95.000000   95.0
# MURUTINGA DO SUL       1           113  113.000000  113.0
# MOTUCA                 1           144  144.000000  144.0
# ZACARIAS               1            78   78.000000   78.0
#
#                  nivel_socio_economico
#                                   mean median
# MUN
# SAO PAULO                     4.164067   4.35
# GUARULHOS                     4.810893   4.95
# CAMPINAS                      3.891875   4.12
# SANTO ANDRE                   3.557701   3.49
# SOROCABA                      4.057692   4.18
# ...                                ...    ...
# NARANDIBA                     4.990000   4.99
# NANTES                        5.440000   5.44
# MURUTINGA DO SUL              4.730000   4.73
# MOTUCA                        4.470000   4.47
# ZACARIAS                      4.450000   4.45
#
# [645 rows x 6 columns]

# %%
sns.jointplot(data=df, x="nivel_socio_economico", y="TotalAlunosEM", hue="MUN")
